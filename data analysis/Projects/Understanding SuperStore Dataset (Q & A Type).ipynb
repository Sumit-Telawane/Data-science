# %%
import numpy as np
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import plotly.graph_objs as go
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_excel('Superstore - Copy.xlsx')

# %%
df.head()
# Out:
#    row id   customer id order date shipping date       ship mode  \
# 0       1  CA2016152156 2023-07-01    2021-07-08    Second Class
# 1       2  CA2016152156 2022-07-03    2023-05-11    Second Class
# 2       3  CA2016138688 2021-08-16    2021-11-02    Second Class
# 3       4  US2015108966 2021-04-14    2022-12-21  Standard Class
# 4       5  US2015108966 2021-01-02    2021-08-26  Standard Class
#
#   customer id.1    customer name    segment        country             city  \
# 0       CG12520      Claire Gute   Consumer  United States        Henderson
# 1       CG12520      Claire Gute   Consumer  United States        Henderson
# 2       DV13045  Darrin Van Huff  Corporate  United States      Los Angeles
# 3       SO20335    Sean ODonnell   Consumer  United States  Fort Lauderdale
# 4       SO20335    Sean ODonnell   Consumer  United States  Fort Lauderdale
#
#    ... postal code  region     product id         category sub category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9990 entries, 0 to 9989
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   row id         9990 non-null   int64
#  1   customer id    9990 non-null   object
#  2   order date     9990 non-null   datetime64[ns]
#  3   shipping date  9990 non-null   datetime64[ns]
#  4   ship mode      9990 non-null   object
#  5   customer id.1  9990 non-null   object
#  6   customer name  9990 non-null   object
#  7   segment        9990 non-null   object
#  8   country        9990 non-null   object
#  9   city           9990 non-null   object
#  10  state          9990 non-null   object
#  11  postal code    9990 non-null   int64
#  12  region         9990 non-null   object
#  13  product id     9990 non-null   object
#  14  category       9990 non-null   object
#  15  sub category   9990 non-null   object
#  16  product name   9990 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['row id', 'customer id', 'order date', 'shipping date', 'ship mode',
#        'customer id.1', 'customer name', 'segment', 'country', 'city', 'state',
#        'postal code', 'region', 'product id', 'category', 'sub category',
#        'product name', 'sales', 'quantity', 'discount', 'profit'],
#       dtype='object')

# %%
df.dtypes
# Out:
# row id                    int64
# customer id              object
# order date       datetime64[ns]
# shipping date    datetime64[ns]
# ship mode                object
# customer id.1            object
# customer name            object
# segment                  object
# country                  object
# city                     object
# state                    object
# postal code               int64
# region                   object
# product id               object
# category                 object
# sub category             object
# product name             object
# sales                   float64
# quantity                  int64
# discount                float64
# profit                  float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# row id           0
# customer id      0
# order date       0
# shipping date    0
# ship mode        0
# customer id.1    0
# customer name    0
# segment          0
# country          0
# city             0
# state            0
# postal code      0
# region           0
# product id       0
# category         0
# sub category     0
# product name     0
# sales            0
# quantity         0
# discount         0
# profit           0
# dtype: int64

# %%
df.describe()
# Out:
#             row id                     order date  \
# count  9990.000000                           9990
# mean   4995.500000  2022-04-18 18:55:08.108108032
# min       1.000000            2021-01-01 00:00:00
# 25%    2498.250000            2021-08-21 00:00:00
# 50%    4995.500000            2022-04-18 00:00:00
# 75%    7492.750000            2022-12-10 00:00:00
# max    9990.000000            2023-08-01 00:00:00
# std    2884.008929                            NaN
#
#                        shipping date   postal code         sales     quantity  \
# count                           9990   9990.000000   9990.000000  9990.000000
# mean   2022-04-18 08:56:04.324324352  55180.614314    229.827353     3.789790
# min              2021-01-01 00:00:00   1040.000000      0.444000     1.000000
# 25%              2021-08-27 00:00:00  23223.000000     17.280000     2.000000
# 50%              2022-04-21 00:00:00  56301.000000     54.432000     3.000000
# ...

# %%
df.nunique()
# Out:
# row id           9990
# customer id      5007
# order date        943
# shipping date     943
# ship mode           4
# customer id.1     793
# customer name     793
# segment             3
# country             1
# city              531
# state              49
# postal code       631
# region              4
# product id       1862
# category            3
# sub category       17
# product name     1849
# sales            5824
# quantity           14
# discount           12
# profit           7066
# dtype: int64

# %% [markdown]
# **What is the range of values for categorical columns?**

# %%
df["region"].value_counts()
# Out:
# region
# West       3200
# East       2848
# Central    2322
# South      1620
# Name: count, dtype: int64

# %%
df.select_dtypes(include=['object']).columns
# Out:
# Index(['customer id', 'ship mode', 'customer id.1', 'customer name', 'segment',
#        'country', 'city', 'state', 'region', 'product id', 'category',
#        'sub category', 'product name'],
#       dtype='object')

# %%
categorical_columns = df.select_dtypes(include=['object']).columns

for column in categorical_columns:
    print(f"Column: {column}")
    print(df[column].value_counts())
    print("\n")
# Out:
# Column: customer id
# customer id
# CA2017100111    14
# CA2017157987    12
# US2016108504    11
# CA2016165330    11
# CA2015131338    10
#                 ..
# CA2016157259     1
# CA2017107986     1
# CA2017109589     1
# CA2016118332     1
# CA2017119914     1
# Name: count, Length: 5007, dtype: int64
#
#
# Column: ship mode
# ship mode
# Standard Class    5967
# Second Class      1942
# First Class       1538
# Same Day           543
# Name: count, dtype: int64
#
#
# Column: customer id.1
# customer id.1
# WB21850    37
# MA17560    34
# JL15835    34
# PP18955    34
# JD15895    32
#            ..
# LD16855     1
# AO10810     1
# CJ11875     1
# RE19405     1
# JR15700     1
# Name: count, Length: 793, dtype: int64
#
#
# Column: customer name
# customer name
# William Brown       37
# Matt Abelman        34
# John Lee            34
# Paul Prost          34
# Jonathan Doherty    32
#                     ..
# Lela Donovan         1
# Anthony ODonnell     1
# ...

# %% [markdown]
# **What is the syntax for selecting rows and columns using iloc and loc in pandas?**

# %%
# Example: Selecting the first three rows and the first two columns
subset = df.iloc[0:3, 0:2]
print(subset)
# Out:
#    row id   customer id
# 0       1  CA2016152156
# 1       2  CA2016152156
# 2       3  CA2016138688

# %%
# Example: Selecting rows with labels 0 through 2 and columns 'column1' through 'column2'
subset = df.loc[0:5, 'category':'sub category']
print(subset)
# Out:
#           category sub category
# 0        Furniture    Bookcases
# 1        Furniture       Chairs
# 2  Office Supplies       Labels
# 3        Furniture       Tables
# 4  Office Supplies      Storage
# 5        Furniture  Furnishings

# %% [markdown]
# **How can you use pandas to create a histogram of a numerical variable?**

# %%
# Plotting a histogram for the 'sales' column with custom bins
plt.hist(df['sales'], edgecolor='black')

# Adding labels and title
plt.title('Histogram of Sales with 2000 Bins')
plt.xlabel('Sales')
plt.ylabel('Frequency')

# Display the histogram
plt.show()

# %% [markdown]
# **Scatter plot**

# %%
# Scatter plot of 'sales' against 'profit'
df.plot.scatter(x='sales', y='profit', edgecolors='black', figsize=(10, 6))

# Adding labels and title
plt.title('Scatter Plot of Sales vs. Profit')
plt.xlabel('Sales')
plt.ylabel('Profit')

# Display the scatter plot
plt.show()

# %% [markdown]
# **Bar chart for the distribution**

# %%
# Bar chart for the distribution of the 'segment' variable
segment_distribution = df['segment'].value_counts()

# Plotting the bar chart
segment_distribution.plot(kind='bar', edgecolor='black', figsize=(10, 6))

# Adding labels and title
plt.title('Distribution of Customer Segments')
plt.xlabel('Segment')
plt.ylabel('Count')

# Display the bar chart
plt.show()

# %% [markdown]
# **How can you sort the dataset based on a specific column?**

# %%
# Sorting the DataFrame based on the 'sales' column in ascending order
df.sort_values(by='sales')
# Out:
#       row id   customer id order date shipping date       ship mode  \
# 4097    4098  US2017102288 2021-10-10    2021-02-16  Standard Class
# 9288    9289  CA2017124114 2022-12-22    2021-11-25        Same Day
# 8654    8655  CA2016168361 2021-06-04    2023-03-13  Standard Class
# 4707    4708  CA2014112403 2021-11-12    2022-05-29        Same Day
# 2102    2103  US2014152723 2022-09-02    2021-02-24        Same Day
# ...      ...           ...        ...           ...             ...
# 4186    4187  CA2017166709 2022-04-19    2021-12-24  Standard Class
# 2619    2620  CA2017127180 2023-01-02    2023-01-12     First Class
# 8149    8150  CA2017140151 2021-03-22    2023-03-03     First Class
# 6822    6823  CA2016118689 2022-01-04    2021-09-04  Standard Class
# 2693    2694  CA2014145317 2021-07-13    2022-08-24  Standard Class
#
#      customer id.1     customer name      segment        country  \
# 4097       ZC21910  Zuschuss Carroll     Consumer  United States
# ...

# %%
# Sorting the DataFrame based on the 'sales' column in descending order
df.sort_values(by='sales', ascending=False)
# Out:
#       row id   customer id order date shipping date       ship mode  \
# 2693    2694  CA2014145317 2021-07-13    2022-08-24  Standard Class
# 6822    6823  CA2016118689 2022-01-04    2021-09-04  Standard Class
# 8149    8150  CA2017140151 2021-03-22    2023-03-03     First Class
# 2619    2620  CA2017127180 2023-01-02    2023-01-12     First Class
# 4186    4187  CA2017166709 2022-04-19    2021-12-24  Standard Class
# ...      ...           ...        ...           ...             ...
# 2102    2103  US2014152723 2022-09-02    2021-02-24        Same Day
# 4707    4708  CA2014112403 2021-11-12    2022-05-29        Same Day
# 8654    8655  CA2016168361 2021-06-04    2023-03-13  Standard Class
# 9288    9289  CA2017124114 2022-12-22    2021-11-25        Same Day
# 4097    4098  US2017102288 2021-10-10    2021-02-16  Standard Class
#
#      customer id.1     customer name      segment        country  \
# 2693       SM20320       Sean Miller  Home Office  United States
# ...

# %%
# Sorting the DataFrame based on 'sales' in ascending order and 'profit' in descending order
df.sort_values(by=['sales', 'profit'], ascending=[True, False])
# Out:
#       row id   customer id order date shipping date       ship mode  \
# 4097    4098  US2017102288 2021-10-10    2021-02-16  Standard Class
# 9288    9289  CA2017124114 2022-12-22    2021-11-25        Same Day
# 8654    8655  CA2016168361 2021-06-04    2023-03-13  Standard Class
# 4707    4708  CA2014112403 2021-11-12    2022-05-29        Same Day
# 2102    2103  US2014152723 2022-09-02    2021-02-24        Same Day
# ...      ...           ...        ...           ...             ...
# 4186    4187  CA2017166709 2022-04-19    2021-12-24  Standard Class
# 2619    2620  CA2017127180 2023-01-02    2023-01-12     First Class
# 8149    8150  CA2017140151 2021-03-22    2023-03-03     First Class
# 6822    6823  CA2016118689 2022-01-04    2021-09-04  Standard Class
# 2693    2694  CA2014145317 2021-07-13    2022-08-24  Standard Class
#
#      customer id.1     customer name      segment        country  \
# 4097       ZC21910  Zuschuss Carroll     Consumer  United States
# ...

# %% [markdown]
# **What is the function to rank values within a column in pandas?**

# %%
# Example: Ranking the 'sales' column in ascending order
df['sales_rank'] = df['sales'].rank()

# Displaying the DataFrame with the new 'sales_rank' column
df[['sales', 'sales_rank']]
# Out:
#          sales  sales_rank
# 0     261.9600      7870.5
# 1     731.9400      9273.0
# 2      14.6200      2117.5
# 3     957.5775      9491.0
# 4      22.3680      3073.0
# ...        ...         ...
# 9985   25.2480      3332.5
# 9986   91.9600      6058.5
# 9987  258.5760      7852.5
# 9988   29.6000      3652.0
# 9989  243.1600      7750.0
#
# [9990 rows x 2 columns]

# %%
df['sales_rank_desc'] = df['sales'].rank(ascending=False)

# Displaying the DataFrame with the new 'sales_rank_desc' column
df[['sales', 'sales_rank_desc']]
# Out:
#          sales  sales_rank_desc
# 0     261.9600           2120.5
# 1     731.9400            718.0
# 2      14.6200           7873.5
# 3     957.5775            500.0
# 4      22.3680           6918.0
# ...        ...              ...
# 9985   25.2480           6658.5
# 9986   91.9600           3932.5
# 9987  258.5760           2138.5
# 9988   29.6000           6339.0
# 9989  243.1600           2241.0
#
# [9990 rows x 2 columns]

# %% [markdown]
# **how to sort and rank data simultaneously?**

# %%
# Sorting the DataFrame based on the 'sales' column in descending order
df_sorted = df.sort_values(by='sales', ascending=False)

# Assigning ranks to the sorted 'sales' column
df_sorted['sales_rank'] = df_sorted['sales'].rank(ascending=False)

# Displaying the sorted and ranked DataFrame
df_sorted[['sales', 'sales_rank']]
# Out:
#           sales  sales_rank
# 2693  22638.480         1.0
# 6822  17499.950         2.0
# 8149  13999.960         3.0
# 2619  11199.968         4.0
# 4186  10499.970         5.0
# ...         ...         ...
# 2102      0.876      9986.0
# 4707      0.852      9987.0
# 8654      0.836      9988.0
# 9288      0.556      9989.0
# 4097      0.444      9990.0
#
# [9990 rows x 2 columns]

# %% [markdown]
# **How can you identify and remove duplicate rows from the dataset?**

# %%
# Identifying duplicate rows
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [row id, customer id, order date, shipping date, ship mode, customer id.1, customer name, segment, country, city, state, postal code, region, product id, category, sub category, product name, sales, quantity, discount, profit, sales_rank, sales_rank_desc]
# Index: []
#
# [0 rows x 23 columns]

# %%
# Removing duplicate rows and creating a new DataFrame
df.drop_duplicates()
# AS there  are no duplicate nothing has removed from dataset
# Out:
#       row id   customer id order date shipping date       ship mode  \
# 0          1  CA2016152156 2023-07-01    2021-07-08    Second Class
# 1          2  CA2016152156 2022-07-03    2023-05-11    Second Class
# 2          3  CA2016138688 2021-08-16    2021-11-02    Second Class
# 3          4  US2015108966 2021-04-14    2022-12-21  Standard Class
# 4          5  US2015108966 2021-01-02    2021-08-26  Standard Class
# ...      ...           ...        ...           ...             ...
# 9985    9986  CA2014110422 2022-04-25    2021-11-15    Second Class
# 9986    9987  CA2017121258 2022-06-29    2022-04-09  Standard Class
# 9987    9988  CA2017121258 2023-06-09    2023-02-18  Standard Class
# 9988    9989  CA2017121258 2022-04-01    2022-01-22  Standard Class
# 9989    9990  CA2017119914 2022-08-29    2022-10-14    Second Class
#
#      customer id.1     customer name    segment        country  \
# 0          CG12520       Claire Gute   Consumer  United States
# ...

# %% [markdown]
# **How can you apply a function to a column in pandas?**

# %%
# Example 1: Applying a function to the 'sales' column
def custom_function(x):
    # Replace this with your custom logic
    return x * 2

df['custom_sales'] = df['sales'].apply(custom_function)

# Displaying the DataFrame with the new column
df[['sales', 'custom_sales']]
# Out:
#          sales  custom_sales
# 0     261.9600       523.920
# 1     731.9400      1463.880
# 2      14.6200        29.240
# 3     957.5775      1915.155
# 4      22.3680        44.736
# ...        ...           ...
# 9985   25.2480        50.496
# 9986   91.9600       183.920
# 9987  258.5760       517.152
# 9988   29.6000        59.200
# 9989  243.1600       486.320
#
# [9990 rows x 2 columns]

# %%
# Example 2: Applying a lambda function to the 'sales' column
df['custom_sales'] = df['sales'].apply(lambda x: x * 2)

# Displaying the DataFrame with the new column
df[['sales', 'custom_sales']]
# Out:
#          sales  custom_sales
# 0     261.9600       523.920
# 1     731.9400      1463.880
# 2      14.6200        29.240
# 3     957.5775      1915.155
# 4      22.3680        44.736
# ...        ...           ...
# 9985   25.2480        50.496
# 9986   91.9600       183.920
# 9987  258.5760       517.152
# 9988   29.6000        59.200
# 9989  243.1600       486.320
#
# [9990 rows x 2 columns]

# %% [markdown]
# **how to create a new column based on existing columns?**

# %%
# Example: Creating a new column 'total_profit' based on 'sales' and 'profit'
df['total_profit'] = df['sales'] - df['profit']

# Displaying the DataFrame with the new column
df[['sales', 'profit', 'total_profit']]
# Out:
#          sales    profit  total_profit
# 0     261.9600   41.9136      220.0464
# 1     731.9400  219.5820      512.3580
# 2      14.6200    6.8714        7.7486
# 3     957.5775  383.0310      574.5465
# 4      22.3680    2.5164       19.8516
# ...        ...       ...           ...
# 9985   25.2480    4.1028       21.1452
# 9986   91.9600   15.6332       76.3268
# 9987  258.5760   19.3932      239.1828
# 9988   29.6000   13.3200       16.2800
# 9989  243.1600   72.9480      170.2120
#
# [9990 rows x 3 columns]

# %% [markdown]
# ## Descriptive Statistics:

# %% [markdown]
# **What is the size of the dataset (number of rows and columns)?**

# %%
# Display the number of rows and columns in the DataFrame
print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])
# Out:
# Number of rows: 9990
# Number of columns: 21

# %% [markdown]
# **What are the basic summary statistics (mean, median, min, max) for numerical columns?**

# %%
df.describe()
# Out:
#             row id   postal code         sales     quantity     discount  \
# count  9990.000000   9990.000000   9990.000000  9990.000000  9990.000000
# mean   4995.500000  55180.614314    229.827353     3.789790     0.156225
# std    2884.008929  32064.346058    623.327164     2.225467     0.206481
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2498.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4995.500000  56301.000000     54.432000     3.000000     0.200000
# 75%    7492.750000  90008.000000    209.937500     5.000000     0.200000
# max    9990.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             profit  custom_sales  total_profit
# count  9990.000000   9990.000000   9990.000000
# mean     59.916593    459.654706    169.910760
# std     228.321164   1246.654329    465.320962
# min       0.000000      0.888000  -2099.993000
# 25%       5.369000     34.560000     10.020300
# ...

# %% [markdown]
# ## Data Cleaning and Handling Missing Values:

# %% [markdown]
# **Are there any missing values in the dataset, and if so, how are they distributed?**

# %%
df.isnull().sum()
# Out:
# row id           0
# customer id      0
# ship mode        0
# customer id.1    0
# customer name    0
# segment          0
# country          0
# city             0
# state            0
# postal code      0
# region           0
# product id       0
# category         0
# sub category     0
# product name     0
# sales            0
# quantity         0
# discount         0
# profit           0
# custom_sales     0
# total_profit     0
# dtype: int64

# %% [markdown]
# **What strategies could be employed to handle missing data?**

# %% [markdown]
# **Complete Case Analysis (CCA):** Remove rows with missing values. This is feasible if the number of missing values is small and the missing values are randomly distributed.
# Imputation:
#
# **Mean/Median/Mode Imputation:** Replace missing values with the mean, median, or mode of the respective column. This is a simple method, but it assumes that the missing values are missing completely at random (MCAR).
# Forward Fill or Backward Fill (for Time Series Data): Propagate the last known value forward or the next known value backward to fill missing values.
#
# **Interpolation:** Estimate missing values based on other values in the dataset, using methods like linear interpolation.
# Predictive Modeling:
#
# **Machine Learning Models:** Use machine learning models to predict missing values based on other features. This can be a powerful approach if there is enough data and the relationship between the features is complex.
#
# **Create a Missing Indicator:** Create an additional binary column indicating whether a value was missing in a specific column. This can be useful if there is a pattern to missingness.
#
# **Domain-specific Methods:** Use domain-specific knowledge to fill in missing values. For example, if missing values are related to a certain category, use the mean of that category.
#
# **Multiple Imputation:** Generate multiple datasets with different imputations for missing values and analyze each dataset separately. This helps capture the uncertainty associated with imputing missing values.
#
# **Deep Learning Techniques:** Use advanced techniques like autoencoders or generative adversarial networks (GANs) to generate missing values based on the existing data distribution.
#
# **note:** *The choice of strategy depends on the nature of the data, the amount of missing data, and the underlying reasons for the missingness. It's crucial to carefully consider the implications of each method and how it might impact downstream analyses.*

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# **What is the distribution of sales across the dataset?**

# %%
# Set the style for better aesthetics
sns.set(style="whitegrid")

# Create subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(16, 6))

# Plotting histogram
sns.histplot(df['sales'], bins=30, kde=True, color='skyblue', ax=axes[0])
axes[0].set_title('Distribution of Sales')
axes[0].set_xlabel('Sales')
axes[0].set_ylabel('Frequency')

# Plotting box plot
sns.boxplot(x=df['sales'], color='lightcoral', ax=axes[1])
axes[1].set_title('Box Plot of Sales')
axes[1].set_xlabel('Sales')

# Adjust layout for better spacing
plt.tight_layout()
plt.show()

# %% [markdown]
# **How is the quantity of products sold distributed?**

# %%
# Set the style for better aesthetics
sns.set(style="whitegrid")

# Create a histogram for quantity
plt.figure(figsize=(10, 6))
sns.histplot(df['quantity'], bins=30, kde=True, color='skyblue')
plt.title('Distribution of Quantity Sold')
plt.xlabel('Quantity')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **What is the proportion of different shipping modes used?**

# %%
# Set a color palette with different shades of a single color
color = sns.color_palette('Blues', len(ship_mode_counts))
color
# Out:
# [(0.8141176470588235, 0.883921568627451, 0.9498039215686275),
#  (0.5796078431372549, 0.7701960784313725, 0.8737254901960784),
#  (0.2909803921568628, 0.5945098039215686, 0.7890196078431373),
#  (0.09019607843137256, 0.39294117647058824, 0.6705882352941177)]

# %%
# Calculate the proportion of each shipping mode
ship_mode_counts = df['ship mode'].value_counts()
labels = ship_mode_counts.index
sizes = ship_mode_counts.values

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, colors=color)
plt.title('Proportion of Shipping Modes')
plt.show()

# %% [markdown]
# ## Bivariate Analysis:

# %% [markdown]
# **Is there a correlation between sales and profit?**

# %%
df['sales'].corr(df['profit'])
# Out:
# 0.7874705783917679

# %% [markdown]
# **How does the discount level impact sales?**

# %%
# Scatter plot
plt.scatter(df['discount'], df['sales'], alpha=0.5)
plt.title('Impact of Discount on Sales')
plt.xlabel('Discount')
plt.ylabel('Sales')
plt.show()

# %%
from scipy.stats import linregress

# Calculate linear regression
slope, intercept, r_value, p_value, std_err = linregress(df['discount'], df['sales'])

print(f'Linear Regression: slope={slope}, intercept={intercept}, r-value={r_value}, p-value={p_value}, std_err={std_err}')
# Out:
# Linear Regression: slope=-85.21723339938644, intercept=243.1404346640729, r-value=-0.028228675544162717, p-value=0.0047775059328750815, std_err=30.194271596718732

# %% [markdown]
# *The r_value in the output represents the correlation coefficient. A positive value indicates a positive correlation, while a negative value indicates a negative correlation.*
#
# *The p_value helps assess the statistical significance of the relationship.*
#
# **Conclusion:** Discount doesn't affect sales

# %% [markdown]
# **What is the relationship between quantity sold and profit?**

# %%
# Scatter plot
plt.scatter(df['quantity'], df['profit'], alpha=0.5)
plt.title('Relationship between Quantity Sold and Profit')
plt.xlabel('Quantity Sold')
plt.ylabel('Profit')
plt.show()

# %%
from scipy.stats import linregress

# Calculate linear regression
slope, intercept, r_value, p_value, std_err = linregress(df['quantity'], df['profit'])

print(f'Linear Regression: slope={slope}, intercept={intercept}, r-value={r_value}, p-value={p_value}, std_err={std_err}')
# Out:
# Linear Regression: slope=14.705509832842093, intercept=4.18580171457441, r-value=0.14333593865627428, p-value=5.246793029709094e-47, std_err=1.015963079054889

# %% [markdown]
# **Conclusion:** Quantity sold affect profits

# %% [markdown]
# ## Temporal Analysis:

# %%
# Set the order date as the index
df.set_index('order date', inplace=True)

# Resample data by month and calculate total sales for each month
monthly_sales = df['sales'].resample('M').sum()

# Time series plot
plt.figure(figsize=(12, 6))
monthly_sales.plot()
plt.title('Monthly Sales Over Time')
plt.xlabel('Time')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# **Are there any significant trends or patterns in the order dates?**

# %%
# Ensure the 'order date' column is in datetime format
df['order date'] = pd.to_datetime(df['order date'], errors='coerce')

# Set the 'order date' as the index
df.set_index('order date', inplace=True)

# Resample data by month and calculate total sales for each month
monthly_sales = df['sales'].resample('M').sum()

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(monthly_sales, marker='o', linestyle='-')
plt.title('Monthly Sales Over Time')
plt.xlabel('Date')
plt.ylabel('Total Sales')
plt.grid(True)
plt.show()

# %% [markdown]
# **What is the average shipping time for orders?**

# %%
# Calculate the shipping time for each order
df['shipping time'] = df['shipping date'] - df['order date']

# Calculate the average shipping time
average_shipping_time = df['shipping time'].mean()

print(f'The average shipping time for orders is: {average_shipping_time}')
# Out:
# The average shipping time for orders is: -1 days +14:00:56.216216217

# %% [markdown]
# ## Geographical Analysis:

# %% [markdown]
# **What is the distribution of sales across different regions?**

# %%
# Set the style of seaborn
sns.set(style="whitegrid")

# Create a bar plot of sales by region
plt.figure(figsize=(10, 6))
sns.barplot(x="region", y="sales", data=df, ci=None, palette="viridis")
plt.title('Distribution of Sales Across Different Regions')
plt.xlabel('Region')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# **Are there specific regions with higher or lower profit margins?**

# %%
# Set the style of seaborn
sns.set(style="whitegrid")

# Create a bar plot of profit by region
plt.figure(figsize=(10, 6))
sns.barplot(x="region", y="profit", data=df, ci=None, palette="coolwarm")
plt.title('Profit Margins Across Different Regions')
plt.xlabel('Region')
plt.ylabel('Profit')
plt.show()

# %% [markdown]
# **How do shipping times vary by region?**

# %%
# Calculate shipping time for each order
df['shipping_time'] = (df['shipping date'] - df['order date']).dt.days  # Extract days from timedelta

# Set the style of seaborn
sns.set(style="whitegrid")

# Create a boxplot of shipping times by region
plt.figure(figsize=(12, 6))
sns.boxplot(x="region", y="shipping_time", data=df, palette="Set3")
plt.title('Shipping Times by Region')
plt.xlabel('Region')
plt.ylabel('Shipping Time (Days)')
plt.show()

# %% [markdown]
# ## Customer Segmentation:

# %% [markdown]
# **Can you identify distinct customer segments based on purchasing behavior?**

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# Select relevant features for clustering
features = ['sales', 'quantity', 'discount', 'profit']

# Extract the selected features
X = df[features]

# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply K-means clustering
kmeans = KMeans(n_clusters=3, random_state=42)
df['cluster'] = kmeans.fit_predict(X_scaled)

# Visualize the clusters
sns.pairplot(df, hue='cluster', vars=features)
plt.show()

# %% [markdown]
# **How does sales performance differ among different customer segments?**

# %%
# Boxplot to compare sales distribution among segments
plt.figure(figsize=(10, 6))
sns.boxplot(x='segment', y='sales', data=df, palette='Set3')
plt.title('Sales Distribution by Customer Segment')
plt.xlabel('Customer Segment')
plt.ylabel('Sales')
plt.show()

# Summary statistics for sales by segment
sales_summary = df.groupby('segment')['sales'].describe()
print(sales_summary)
# Out:
#               count        mean         std    min     25%    50%      75%  \
# segment
# Consumer     5187.0  223.669895  585.653740  0.444  17.264  53.70  206.046
# Corporate    3020.0  233.823300  599.410408  0.556  17.469  56.54  212.895
# Home Office  1783.0  240.972041  755.516379  0.990  17.045  52.44  210.906
#
#                   max
# segment
# Consumer     13999.96
# Corporate    17499.95
# Home Office  22638.48

# %% [markdown]
# ## Time Series Analysis:

# %% [markdown]
# **Are there any seasonality or trend patterns in the time series data?**

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# 'order date' is the index and 'sales' is the time series data
df.set_index('order date', inplace=True)

# Perform seasonal decomposition
result = seasonal_decompose(df['sales'], model='additive', period=12)  # Assuming a yearly seasonality

# Plot the components
plt.figure(figsize=(12, 8))

plt.subplot(4, 1, 1)
plt.plot(result.observed, label='Observed')
plt.legend()
plt.ylabel('Observed Sales')

plt.subplot(4, 1, 2)
plt.plot(result.trend, label='Trend')
plt.legend()
plt.ylabel('Trend')

plt.subplot(4, 1, 3)
plt.plot(result.seasonal, label='Seasonal')
plt.legend()
plt.ylabel('Seasonal Component')

plt.subplot(4, 1, 4)
plt.plot(result.resid, label='Residual')
plt.legend()
plt.ylabel('Residual')

plt.xlabel('Order Date')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Can you forecast future sales based on historical data?**

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA

# Assuming 'order date' is the index and 'sales' is the time series data
# df.set_index('order date', inplace=True)

# Fit an ARIMA model
model = ARIMA(df['sales'], order=(5, 1, 2))  # You may need to adjust the order based on model diagnostics
result = model.fit()

# Forecast future sales
forecast_steps = 12  # You can adjust the number of steps into the future
forecast_index = pd.date_range(start=df.index[-1], periods=forecast_steps + 1, freq='M')[1:]
forecast = result.get_forecast(steps=forecast_steps)

# Plot the historical sales and forecast
plt.figure(figsize=(12, 6))
plt.plot(df['sales'], label='Historical Sales')
plt.plot(forecast_index, forecast.predicted_mean, label='Forecasted Sales', color='red')
plt.fill_between(forecast_index, forecast.conf_int().iloc[:, 0], forecast.conf_int().iloc[:, 1], color='red', alpha=0.2)

plt.xlabel('Order Date')
plt.ylabel('Sales')
plt.legend()
plt.title('Historical Sales and Forecast')
plt.show()
# Out:
# C:\Users\Sumit\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Sumit\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Sumit\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ...

# %% [markdown]
# ## Hypothesis Testing:

# %% [markdown]
# **Is there a statistically significant difference in sales between different regions?**

# %%
import scipy.stats as stats

regions = df['region'].unique()

# Create a dictionary to store sales data for each region
sales_by_region = {region: df[df['region'] == region]['sales'] for region in regions}

# Perform one-way ANOVA
anova_result = stats.f_oneway(*sales_by_region.values())

# Check the p-value to determine statistical significance
alpha = 0.05
if anova_result.pvalue < alpha:
    print(f"ANOVA result is statistically significant (p-value: {anova_result.pvalue}). There is a difference in sales between regions.")
else:
    print(f"ANOVA result is not statistically significant (p-value: {anova_result.pvalue}). There is no significant difference in sales between regions.")
# Out:
# ANOVA result is not statistically significant (p-value: 0.49251216498007055). There is no significant difference in sales between regions.

# %% [markdown]
# **Can you test if the average profit differs for orders with and without discounts?**

# %%
import scipy.stats as stats

profit_with_discount = df[df['discount'] > 0]['profit']
profit_without_discount = df[df['discount'] == 0]['profit']

# Perform independent two-sample t-test
t_statistic, p_value = stats.ttest_ind(profit_with_discount, profit_without_discount, equal_var=False)

# Check the p-value to determine statistical significance
alpha = 0.05
if p_value < alpha:
    print(f"T-test result is statistically significant (p-value: {p_value}). There is a difference in average profit between orders with and without discounts.")
else:
    print(f"T-test result is not statistically significant (p-value: {p_value}). There is no significant difference in average profit between orders with and without discounts.")
# Out:
# T-test result is statistically significant (p-value: 0.0035215983229187117). There is a difference in average profit between orders with and without discounts.

# %% [markdown]
# **What factors significantly contribute to variations in sales or profit?**

# %%
import statsmodels.api as sm

X = df[['profit', 'discount']]  # Add relevant independent variables
y = df['sales']

# Add a constant term to the independent variables
X = sm.add_constant(X)

# Fit the regression model
model = sm.OLS(y, X).fit()

# Print the regression summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.623
# Model:                            OLS   Adj. R-squared:                  0.623
# Method:                 Least Squares   F-statistic:                     8254.
# Date:                Sat, 02 Dec 2023   Prob (F-statistic):               0.00
# Time:                        22:28:49   Log-Likelihood:                -73588.
# No. Observations:                9990   AIC:                         1.472e+05
# Df Residuals:                    9987   BIC:                         1.472e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        126.3810      4.887     25.860      0.000     116.801     135.961
# ...

# %% [markdown]
# ## Let's go through the key information provided in the regression summary:
#
# 1. **Dependent Variable (`sales`):**
#    - The dependent variable in your regression analysis is `sales`. This is the variable you are trying to predict based on the independent variables.
#
# 2. **Model Fit (`R-squared` and `Adj. R-squared`):**
#    - `R-squared`: Represents the proportion of the variance in the dependent variable that is predictable from the independent variables. In your model, approximately 62.3% of the variance in sales is explained by the independent variables.
#    - `Adj. R-squared`: Similar to `R-squared` but adjusts for the number of independent variables in the model.
#
# 3. **F-statistic and Probability (`F-statistic` and `Prob (F-statistic)`):**
#    - `F-statistic`: Tests the hypothesis that all coefficients in the model are zero (i.e., the model has no explanatory power). In your case, the F-statistic is quite high (8254), and the associated p-value is very close to zero, indicating that the model is statistically significant.
#
# 4. **Coefficients (`const`, `profit`, `discount`):**
#    - `const`: This is the intercept term in the regression equation. It represents the estimated value of `sales` when all independent variables are zero. In your case, it is 126.3810.
#    - `profit`: The coefficient represents the change in the dependent variable (`sales`) for a one-unit change in `profit`. In your case, for each unit increase in profit, sales are estimated to increase by 2.1548 units.
#    - `discount`: Similarly, for each unit increase in the `discount`, sales are estimated to decrease by 164.2460 units.
#
# 5. **Hypothesis Testing (`P>|t|`):**
#    - The p-values associated with each coefficient test the null hypothesis that the corresponding coefficient is equal to zero. In your case, both `profit` and `discount` have p-values close to zero, indicating that they are statistically significant.
#
# 6. **Model Diagnostics (`Omnibus`, `Durbin-Watson`, `Jarque-Bera`, `Skew`, `Kurtosis`):**
#    - These are diagnostic statistics that assess various aspects of the model's performance.
#    - `Omnibus`: Tests the normality of the residuals. A p-value close to zero suggests non-normality.
#    - `Durbin-Watson`: Tests for autocorrelation in the residuals. A value around 2 indicates no autocorrelation.
#    - `Jarque-Bera`: Another test for normality. A significant p-value suggests non-normality.
#    - `Skew`: Measures the skewness of the residuals.
#    - `Kurtosis`: Measures the kurtosis (tailedness) of the residuals.
#
# 7. **Other Notes:**
#    - The note about standard errors assumes that the covariance matrix of the errors is correctly specified.
#    - The condition number is large, which might indicate strong multicollinearity or other numerical problems. It's essential to check for multicollinearity in your data.
#
# Overall, the regression model seems to be statistically significant, and the coefficients provide insights into the relationships between the independent and dependent variables.
