# %%
# import pandas as pd
from datetime import datetime
import time
import re
import tabulate
# from IPython.display import display

# Function to load user data from CSV
def load_users():
    try:
        # Attempt to read user data from CSV file
        users_df = pd.read_csv('users.csv')
    except FileNotFoundError:
        # Create an empty DataFrame if the file doesn't exist
        users_df = pd.DataFrame(columns=['Username', 'Password', 'LastLogin'])
        users_df.to_csv('users.csv', index=False, mode='a')
    return users_df

# Function for user registration
def register(username, password):
    users_df = load_users()

    # Password validation regex
    password_regex = re.compile(r'^(?=.*[A-Za-z])(?=.*\d)(?=.*[@$!%*#?&])[A-Za-z\d@$!%*#?&]{3,}$')

    if username in users_df['Username'].values:
        # Check if the username already exists
        print("Username already exists. Please choose another one.")
    elif not password_regex.match(password):
        # Validate the password format
        print("Invalid password. Password must contain at least one letter, one number, and one special character (@$!%*#?&), and have a minimum length of 3.")
    else:
        current_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        
        # Create a new user DataFrame
        new_user = pd.DataFrame({'Username': [username], 'Password': [password], 'LastLogin': [current_time]})
        
        # Save the new user to the CSV file
        new_user.to_csv('users.csv', index=False, mode='a', header=False)
        print(f"Registration successful. Welcome, {username}!")

# Function to load order history from CSV
def load_orders():
    try:
        # Attempt to read order data from CSV file
        orders_df = pd.read_csv('orders.csv')
    except FileNotFoundError:
        # Create an empty DataFrame if the file doesn't exist
        orders_df = pd.DataFrame(columns=['Username', 'Item', 'Quantity', 'TotalPrice', 'OrderTime'])
        orders_df.to_csv('orders.csv', index=False, header=True, mode='a')
        return orders_df

    return orders_df

# Function for user login
def login(username, password):
    users_df = load_users()
    if (username in users_df['Username'].values) and (password == users_df.loc[users_df['Username'] == username, 'Password'].values[0]):
        # Successful login
        last_login = users_df.loc[users_df['Username'] == username, 'LastLogin'].values[0]
        current_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        users_df.loc[users_df['Username'] == username, 'LastLogin'] = current_time
        users_df.to_csv('users.csv', index=False)
        print(f"Welcome back, {username}! Last login: {last_login}")
        return True
    else:
        # Invalid username or password
        print("Invalid username or password. Please try again.")
        return False

# Function to load menu from CSV
def load_menu():
    try:
        # Attempt to read menu data from CSV file
        menu_df = pd.read_csv('menu.csv')
    except FileNotFoundError:
        # Create an empty DataFrame if the file doesn't exist
        print("Menu file not found.")
        menu_df = pd.DataFrame(columns=['Item', 'Price'])
        menu_df.to_csv('menu.csv', index=False, mode='a')
    return menu_df

# Function to display menu

# for jupiter

# def display_menu():
#     menu_df = load_menu()
#     menu_df.index += 1  # Shift the index to start from 1
#     print("Menu:")
#     display(menu_df)


def display_menu():
    menu_df = load_menu()
    menu_df.index += 1  # Shift the index to start from 1
    print("Menu:")
    print(tabulate.tabulate(menu_df, headers='keys', tablefmt='pretty', showindex=True))

quantity = 0

# Function to take order
def take_order():
    global quantity  # Use the global quantity variable
    menu_df = load_menu()
    while True:
        try:
            choice = int(input("Enter the number of the item you want to order: "))
            if 1 <= choice <= len(menu_df):
                quantity = int(input("Enter the quantity: "))  # Set the global quantity variable
                return menu_df.loc[choice - 1, 'Item']
            else:
                print("Invalid choice. Please enter a valid number.")
        except ValueError:
            print("Invalid input. Please enter a number.")
            
def get_price(item_name):
    df = load_menu()
    """Get the price of a specific item."""
    
    item_row = df[df['Item'].str.lower() == item_name.lower()]
    
    if not item_row.empty:
        return item_row['Price'].values[0]
    else:
        return "Item not found"
            
def prepare_drink(order):
    # Simulate drink preparation
    print(f"Preparing {order}...")
    time.sleep(0.3)
    total_orders.append(order)

def order_serve(order):
    # Serve the prepared order
    print(f"Here is your {order}.")

def show_bill(order):
    # Display the bill for the ordered item, multiplied by the quantity
    orignal_price = price = get_price(order)
    price = get_price(order) * quantity
    
    print(f"Item: {order}, Orignal Price: {orignal_price}, Quantity: {quantity}, Total Price: Rs.{price:.2f}")

def check_payment(price):
    # Check if the payment amount is sufficient
    bill_amount = price
    amount_due = price  # Initialize amount_due with the total bill amount

    while amount_due > 0:
        try:
            payment = float(input(f"Enter your payment amount (Amount due: Rs.{amount_due:.2f}): Rs."))
            if payment < 0:
                print("Invalid payment amount. Please enter a positive value.")
            elif payment < amount_due:
                amount_due -= payment
                print(f"Payment amount received: Rs.{payment:.2f}. Amount pending: Rs.{amount_due:.2f}")
            else:
                amount_due -= payment
                if amount_due == 0:
                    print("Thank you! Payment received.")
                else:
                    print(f"Thank you! Payment received. Change: Rs.{-amount_due:.2f}")
                break
        except ValueError:
            # Handle invalid payment input (non-numeric)
            print("Invalid input. Please enter a valid payment amount.")

    return amount_due


def thank_you():
    # Display a thank-you message
    print("Thank you for ordering from our Cafe!")

# Function to place an order
def place_order(username):
    global quantity  # Use the global quantity variable
    menu_df = pd.read_csv('menu.csv')
    display_menu()

    item = take_order()

    # Check if the item exists in the menu
    if item not in menu_df['Item'].values:
        print("Invalid item. Please choose a valid item from the menu.")
        return

    total_price = get_price(item) * quantity

    order_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    new_orders = pd.DataFrame({'Username': [username], 'Item': [item], 'Quantity': [quantity], 'TotalPrice': [total_price], 'OrderTime': [order_time]})
    new_orders.to_csv('orders.csv', index=False, mode='a', header=False)
    print("Order placed successfully!")

    prepare_drink(item)
    order_serve(item)
    show_bill(item)
    check_payment(total_price)

# Function to view previous orders
def view_previous_orders(username):
    orders_df = load_orders()
    user_orders = orders_df[orders_df['Username'] == username]
    if user_orders.empty:
        print("No previous orders.")
    else:
        print("\nPrevious Orders:")
        print(user_orders)

# Function to display the main menu
def main_menu():
    # Display the main menu options
    print("\nMain Menu:")
    print("1. Place an order")
    print("2. View previous orders")
    print("3. Logout")

# Main program
def cafe_shop():
    # Main entry point for the cafe shop management system

    print("Welcome to the Cafe Shop Management System!")

    while True:
        # Main loop for user interactions
        print("\n1. Register\n2. Login\n3. Exit")
        choice = input("Enter your choice: ")

        if choice == '1':
            # User registration
            username = input("Enter your username: ")
            password = str(input("Enter your password: "))
            register(username, password)
        elif choice == '2':
            # User login
            username = input("Enter your username: ")
            password = str(input("Enter your password: "))
            if login(username, password):
                while True:
                    # Sub-menu for logged-in users
                    main_menu()
                    option = input("Enter your choice: ")
                    if option == '1':
                        # Place an order
                        place_order(username)
                    elif option == '2':
                        # View previous orders
                        view_previous_orders(username)
                    elif option == '3':
                        # Logout
                        print("Logging out. Goodbye!")
                        break
                    else:
                        # Invalid option
                        print("Invalid option. Please try again.")
        elif choice == '3':
            # Exit the program
            print("Exiting. Goodbye!")
            break
        else:
            # Invalid choice
            print("Invalid choice. Please try again.")

if __name__ == "__main__":
    # Start the cafe shop management system
    total_orders = [] #Added Global List for Total Orders:
    cafe_shop()
# Out:
# Welcome to the Cafe Shop Management System!
#
# 1. Register
# 2. Login
# 3. Exit
# Enter your choice: 2
# Enter your username: a
# Enter your password: a
# Welcome back, a! Last login: 2023-11-30 21:03:14
#
# Main Menu:
# 1. Place an order
# 2. View previous orders
# 3. Logout
# Enter your choice: 2
#
# Previous Orders:
#    Username                   Item  Quantity  TotalPrice            OrderTime
# 9         a            Iced Coffee       2.0       140.0  2023-11-28 21:55:48
# 10        a                    Tea       4.0        40.0  2023-11-28 22:07:17
# 11        a             Cappuccino       5.0       875.0  2023-11-28 22:15:08
# 12        a                 Coffee       3.0        60.0  2023-11-28 22:16:02
# 13        a                  Latte       3.0       705.0  2023-11-28 22:25:25
# 14        a                    Tea       3.0        30.0  2023-11-28 22:29:26
# 15        a  Cranberry-nut muffins       1.0        50.0  2023-11-30 20:57:25
# 16        a  Cranberry-nut muffins       1.0        50.0  2023-11-30 21:02:12
# 17        a   Greek Yogurt Parfait       4.0       320.0  2023-11-30 21:03:31
#
# Main Menu:
# 1. Place an order
# 2. View previous orders
# 3. Logout
# Enter your choice: 1
# Menu:
#                Category                                        Item  Price
# 0          Bakery Items                       Cranberry-nut muffins     50
# 1                   NaN     Brownies with German chocolate frosting     60
# 2                   NaN                              Chocolate cake     80
# 3                   NaN             Cherry, peach, or apple cobbler     70
# 4                   NaN             Cupcakes with generous frosting     55
# 5                   NaN                               Filled donuts     40
# 6                   NaN                                 Lemon tarts     65
# 7                   NaN                           Almond croissants     75
# 8                   NaN                    Cinnamon roll cappuccino     85
# 9                   NaN                                   Pecan Pie     90
# 10                  NaN                            Blueberry Scones     65
# 11                  NaN                                Banana Bread     80
# 12                  NaN                               Apple Strudel     85
# 13                  NaN                Cheesecake (various flavors)    100
# 14                  NaN                             Danish Pastries     75
# 15                  NaN                             Red Velvet Cake     95
# 16                  NaN                           Coconut Macaroons     70
# 17                  NaN                                 Coffee Cake     75
# 18     Coffee Beverages                                Matcha latte     90
# 19                  NaN                             Nitro cold brew    100
# 20                  NaN                           Vietnamese coffee     95
# 21                  NaN                                Irish coffee    110
# 22                  NaN                                   Americano     70
# 23                  NaN                                  Cappuccino     80
# 24                  NaN                             Double Espresso     75
# 25                  NaN                                       Latte     85
# 26                  NaN                                   Macchiato     75
# 27                  NaN                              Mint Chocolate     95
# 28                  NaN                                       Mocha     90
# 29                  NaN                                 White Mocha    100
# 30                  NaN                                 ICE BLENDED    110
# 31                  NaN                                     Caramel     85
# 32                  NaN                                Coffee Jelly     75
# 33                  NaN                           Cookies and Cream     90
# 34                  NaN                              Hazelnut Mocha     95
# 35                  NaN                                Matcha Cream     90
# 36                  NaN                         Mint Chocolate Chip     90
# 37                  NaN                            Strawberry Cream     95
# 38                  NaN                                Vanilla Bean     80
# 39        Tea Varieties                                   Green Tea     60
# 40                  NaN                                 Jasmine Tea     65
# 41                  NaN                               Chamomile Tea     70
# 42                  NaN                               Earl Grey Tea     75
# 43                  NaN                              Peppermint Tea     65
# 44                  NaN                                Hibiscus Tea     80
# 45                  NaN                                 Rooibos Tea     85
# 46                  NaN                                    Chai Tea     60
# 47                  NaN                                  Oolong Tea     90
# 48                  NaN                                   Black Tea     55
# 49                  NaN                                   White Tea     95
# 50                  NaN    Tea Infusions (rosemary, lavender, etc.)     70
# 51  Other Hot Beverages                                    Espresso     60
# 52                  NaN                                  Long Black     70
# 53                  NaN                                  Flat White     75
# 54                  NaN                                       Decaf     65
# 55                  NaN                                 Cafe' Latte     80
# 56                  NaN                                 Mug a chino     85
# 57                  NaN                               Hot Chocolate     90
# 58       Cold Beverages                                 Iced coffee     80
# 59                  NaN                              Iced chocolate     85
# 60                  NaN          Fresh Fruit Lemonades (for summer)     80
# 61     Additional Items             Affogato (espresso over gelato)    100
# 62                  NaN                              Turkish Coffee     85
# 63                  NaN                        Honey Lavender Latte     95
# 64                  NaN                                   Acai Bowl     95
# 65                  NaN                               Avocado Toast     90
# 66                  NaN                        Greek Yogurt Parfait     80
# 67                  NaN                                Quinoa Salad    100
# 68                  NaN                           Vegan Baked Goods     75
# 69                  NaN                           Protein Smoothies     90
# 70                  NaN            Pumpkin Spice Muffins (for fall)     70
# 71                  NaN               Peppermint Mocha (for winter)     95
# 72                  NaN  Gingerbread Latte (for the holiday season)     90
# 73                  NaN                  Spinach and Feta Croissant     85
# 74                  NaN                            Caprese Sandwich     90
# 75                  NaN                             Quiche Lorraine     95
# 76                  NaN                         Smoked Salmon Bagel    100
# 77                  NaN                      Gourmet Grilled Cheese     80
# Enter the number of the item you want to order: 56
# Enter the quantity: 3
# Order placed successfully!
# Preparing Cafe' Latte...
# Here is your Cafe' Latte.
# Item: Cafe' Latte, Orignal Price: 80, Quantity: 3, Total Price: Rs.240.00
# Enter your payment amount (Amount due: Rs.240.00): Rs.300
# Thank you! Payment received. Change: Rs.60.00
#
# Main Menu:
# 1. Place an order
# 2. View previous orders
# 3. Logout
# Enter your choice: 3
# Logging out. Goodbye!
#
# 1. Register
# 2. Login
# 3. Exit
# Enter your choice: 3
# Exiting. Goodbye!

# %%
import pandas as pd

# %%
df = pd.read_csv("menu.csv")

# %%
import tabulate
def display_menu():
    menu_df = df
    menu_df.index += 1  # Shift the index to start from 1
    print("Menu:")
    print(tabulate.tabulate(menu_df, headers='keys', tablefmt='pretty', showindex=True))
display_menu()
# Out:
# Menu:
# +----+---------------------+--------------------------------------------+-------+
# |    |      Category       |                    Item                    | Price |
# +----+---------------------+--------------------------------------------+-------+
# | 6  |    Bakery Items     |           Cranberry-nut muffins            |  50   |
# | 7  |         nan         |  Brownies with German chocolate frosting   |  60   |
# | 8  |         nan         |               Chocolate cake               |  80   |
# | 9  |         nan         |      Cherry, peach, or apple cobbler       |  70   |
# | 10 |         nan         |      Cupcakes with generous frosting       |  55   |
# | 11 |         nan         |               Filled donuts                |  40   |
# | 12 |         nan         |                Lemon tarts                 |  65   |
# | 13 |         nan         |             Almond croissants              |  75   |
# | 14 |         nan         |          Cinnamon roll cappuccino          |  85   |
# | 15 |         nan         |                 Pecan Pie                  |  90   |
# | 16 |         nan         |              Blueberry Scones              |  65   |
# | 17 |         nan         |                Banana Bread                |  80   |
# | 18 |         nan         |               Apple Strudel                |  85   |
# | 19 |         nan         |        Cheesecake (various flavors)        |  100  |
# | 20 |         nan         |              Danish Pastries               |  75   |
# | 21 |         nan         |              Red Velvet Cake               |  95   |
# | 22 |         nan         |             Coconut Macaroons              |  70   |
# | 23 |         nan         |                Coffee Cake                 |  75   |
# | 24 |  Coffee Beverages   |                Matcha latte                |  90   |
# | 25 |         nan         |              Nitro cold brew               |  100  |
# | 26 |         nan         |             Vietnamese coffee              |  95   |
# | 27 |         nan         |                Irish coffee                |  110  |
# | 28 |         nan         |                 Americano                  |  70   |
# | 29 |         nan         |                 Cappuccino                 |  80   |
# | 30 |         nan         |              Double Espresso               |  75   |
# | 31 |         nan         |                   Latte                    |  85   |
# | 32 |         nan         |                 Macchiato                  |  75   |
# | 33 |         nan         |               Mint Chocolate               |  95   |
# | 34 |         nan         |                   Mocha                    |  90   |
# | 35 |         nan         |                White Mocha                 |  100  |
# | 36 |         nan         |                ICE BLENDED                 |  110  |
# | 37 |         nan         |                  Caramel                   |  85   |
# | 38 |         nan         |                Coffee Jelly                |  75   |
# | 39 |         nan         |             Cookies and Cream              |  90   |
# | 40 |         nan         |               Hazelnut Mocha               |  95   |
# | 41 |         nan         |                Matcha Cream                |  90   |
# | 42 |         nan         |            Mint Chocolate Chip             |  90   |
# | 43 |         nan         |              Strawberry Cream              |  95   |
# | 44 |         nan         |                Vanilla Bean                |  80   |
# | 45 |    Tea Varieties    |                 Green Tea                  |  60   |
# | 46 |         nan         |                Jasmine Tea                 |  65   |
# | 47 |         nan         |               Chamomile Tea                |  70   |
# | 48 |         nan         |               Earl Grey Tea                |  75   |
# | 49 |         nan         |               Peppermint Tea               |  65   |
# | 50 |         nan         |                Hibiscus Tea                |  80   |
# | 51 |         nan         |                Rooibos Tea                 |  85   |
# | 52 |         nan         |                  Chai Tea                  |  60   |
# | 53 |         nan         |                 Oolong Tea                 |  90   |
# | 54 |         nan         |                 Black Tea                  |  55   |
# | 55 |         nan         |                 White Tea                  |  95   |
# | 56 |         nan         |  Tea Infusions (rosemary, lavender, etc.)  |  70   |
# | 57 | Other Hot Beverages |                  Espresso                  |  60   |
# | 58 |         nan         |                 Long Black                 |  70   |
# | 59 |         nan         |                 Flat White                 |  75   |
# | 60 |         nan         |                   Decaf                    |  65   |
# | 61 |         nan         |                Cafe' Latte                 |  80   |
# | 62 |         nan         |                Mug a chino                 |  85   |
# | 63 |         nan         |               Hot Chocolate                |  90   |
# | 64 |   Cold Beverages    |                Iced coffee                 |  80   |
# | 65 |         nan         |               Iced chocolate               |  85   |
# | 66 |         nan         |     Fresh Fruit Lemonades (for summer)     |  80   |
# | 67 |  Additional Items   |      Affogato (espresso over gelato)       |  100  |
# | 68 |         nan         |               Turkish Coffee               |  85   |
# | 69 |         nan         |            Honey Lavender Latte            |  95   |
# | 70 |         nan         |                 Acai Bowl                  |  95   |
# | 71 |         nan         |               Avocado Toast                |  90   |
# | 72 |         nan         |            Greek Yogurt Parfait            |  80   |
# | 73 |         nan         |                Quinoa Salad                |  100  |
# | 74 |         nan         |             Vegan Baked Goods              |  75   |
# | 75 |         nan         |             Protein Smoothies              |  90   |
# | 76 |         nan         |      Pumpkin Spice Muffins (for fall)      |  70   |
# | 77 |         nan         |       Peppermint Mocha (for winter)        |  95   |
# | 78 |         nan         | Gingerbread Latte (for the holiday season) |  90   |
# | 79 |         nan         |         Spinach and Feta Croissant         |  85   |
# | 80 |         nan         |              Caprese Sandwich              |  90   |
# | 81 |         nan         |              Quiche Lorraine               |  95   |
# | 82 |         nan         |            Smoked Salmon Bagel             |  100  |
# | 83 |         nan         |           Gourmet Grilled Cheese           |  80   |
# +----+---------------------+--------------------------------------------+-------+
